# %%
import pandas as pd
from pathlib import Path

# %%
# Import fastf1_lap_dataset.csv

df = pd.read_csv("fastf1_lap_dataset.csv")
df
# Out:
#        year                  round session_name  \
# 0      2018  Australian Grand Prix         Race
# 1      2018  Australian Grand Prix         Race
# 2      2018  Australian Grand Prix         Race
# 3      2018  Australian Grand Prix         Race
# 4      2018  Australian Grand Prix         Race
# ...     ...                    ...          ...
# 22331  2018   Abu Dhabi Grand Prix         Race
# 22332  2018   Abu Dhabi Grand Prix         Race
# 22333  2018   Abu Dhabi Grand Prix         Race
# 22334  2018   Abu Dhabi Grand Prix         Race
# 22335  2018   Abu Dhabi Grand Prix         Race
#
#                                               circuit_id driver_number  \
# 0             FORMULA 1 2018 ROLEX AUSTRALIAN GRAND PRIX           HAM
# 1             FORMULA 1 2018 ROLEX AUSTRALIAN GRAND PRIX           RAI
# 2             FORMULA 1 2018 ROLEX AUSTRALIAN GRAND PRIX           VET
# 3             FORMULA 1 2018 ROLEX AUSTRALIAN GRAND PRIX           MAG
# ...

# %%
df["safety_car_this_lap	"].describe()
# Out:
# count     22336
# unique        2
# top       False
# freq      20833
# Name: rainfall, dtype: object
